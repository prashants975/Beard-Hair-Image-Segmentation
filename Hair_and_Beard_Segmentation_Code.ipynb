# %%
## Train
# !yolo segment train data=/dataset/data.yaml model=yolov8l-seg.pt batch = 16 epochs=200 patience = 25 imgsz=640 plots=True
# Out:
# ...
# 100% 88.1M/88.1M [00:01<00:00, 51.8MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
## Validation
# !yolo segment val data=/dataset/data.yaml model=/models/best_hair_117_epoch_v4.pt
# Out:
# 2023-04-19 03:06:43.828795: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-19 03:06:45.270638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45913430 parameters, 0 gradients, 220.1 GFLOPs
# val: Scanning /content/face_stuffs-4/valid/labels.cache... 70 images, 3 backgrounds, 0 corrupt: 100% 70/70 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 5/5 [00:08<00:00,  1.72s/it]
# ...

# %%
## Predict/ Test
# !yolo segment predict model=/content/runs/segment/train/weights/best.pt conf=0.40 source=/content/drive/MyDrive/hair_video_1.mp4 save=True
# Out:
# 2023-04-19 03:09:44.603694: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-19 03:09:45.482153: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45913430 parameters, 0 gradients, 220.1 GFLOPs
# video 1/1 (1/1643) /content/drive/MyDrive/hair_video_1.mp4: 640x384 1 hair, 111.2ms
# video 1/1 (2/1643) /content/drive/MyDrive/hair_video_1.mp4: 640x384 1 hair, 40.8ms
# video 1/1 (3/1643) /content/drive/MyDrive/hair_video_1.mp4: 640x384 1 hair, 40.8ms
# video 1/1 (4/1643) /content/drive/MyDrive/hair_video_1.mp4: 640x384 1 hair, 40.8ms
# ...

# %%
# !cp /content/runs/segment/predict3/hair_video_1.mp4 /content/drive/MyDrive/hair_out

# %%
# !yolo segment predict model=/content/runs/segment/train/weights/best.pt conf=0.40 source=/content/drive/MyDrive/hair_video_2.mp4 save=True

# %%
# !cp /content/runs/segment/predict/hair_video_2.mp4 /content/drive/MyDrive/hair_out

# %%
# !yolo segment predict model=/content/runs/segment/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/hair_video_4.mp4 save=True

# %%
# !cp /content/runs/segment/predict5/hair_video_4.mp4 /content/drive/MyDrive/hair_out

# %%
# !yolo segment predict model=/content/drive/MyDrive/best_hair_117_epoch_v4.pt conf=0.25 source=/content/drive/MyDrive/factory_video_1.mp4 save=True

# %%
# !cp /content/runs/segment/predict/factory_video_1.mp4 /content/drive/MyDrive/hair_out
